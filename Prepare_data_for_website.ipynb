# %% [markdown]
# # Extract the DrumMidis.zip and SavedSession**.zip files

# %%
import zipfile
import os
import bz2
from umap import UMAP

from bokeh.palettes import inferno, Category20b
from bokeh.core.enums import MarkerType
from bokeh.plotting import figure, show, save
from bokeh.io import output_notebook, reset_output
# output_notebook()


def extract_zip(zip_file, extract_dir):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

def extract_bz2(bz2_file, extract_dir):
    """
    Extract a BZ2 compressed file.
    
    :param bz2_file: Path to the BZ2 compressed file.
    :param extract_dir: Directory where the decompressed contents will be saved.
    """
    # Ensure the extraction directory exists
    os.makedirs(extract_dir, exist_ok=True)

    # Open the BZ2 file for reading
    with bz2.open(bz2_file, 'rb') as file_in:
        # Decompress the data
        data = file_in.read()
        
        # Write the decompressed data to the output file
        with open("temp.zip", 'wb') as file_out:
            file_out.write(data)
        
        extract_zip("temp.zip", extract_dir)
        
        os.remove("temp.zip")
    
if not os.path.exists('DrumMidis'):
    extract_zip('DrumMidis.zip', 'DrumMidis')
    
if not os.path.exists('SavedSessions'):
    extract_bz2('SavedSessions.bz2', 'SavedSessions')

# %% [markdown]
# # Load Bongosero Collection
#
#
# ```
# collection
# |
# |------------ User1
# |            |------------ Attempts
# |            |            |------------ Attempt1
# |            |            |------------ Attempt2
# |            |            |------------ ...
# ```

# %%
from API import ElBongoseroCollection

collection = ElBongoseroCollection('SavedSessions/SavedSessions')
collection
# Out:
# ElBongoseroCollection with 3286 users, total of 6640 attempts

# %% [markdown]
# # Subsetting
#
# You can Subset using the following methods, the returned subset will also be of type `ElBongoseroCollection`
#
# Also, subsetters can be cascaded one after the other
#
# Available subsetters:
# - `filter_by_assessment_duration_minimumm(min_duration)` --> the amount user thought about rating their performance
# - `filter_by_attempt_duration_minimum(min_duration)` --> the amount of time the user spent on the attempt
# - `filter_by_self_assessment_within_range(min_rating, max_rating)` --> the user's self assessment of their performance
# - `filter_by_tempo_range(min_tempo, max_tempo)` --> the tempo of the drum loop
# -  `filter_by_total_bongo_hits_within_range(min_hits, max_hits)` --> the total number of bongo hits in the loop (use to get rid of empty loops)
# - `filter_by_style(style)` --> the style of the drum loop
# - `filter_by_user_level_of_musical_experience(min_, max_)` --> the user's level of musical experience
# - `filter_by_user_exhibion_rating(min_, max_)` --> the user's rating of their experience with the installation
# -

# %%
# available styles
styles = collection.get_all_styles()

subset = collection.filter_by_style('Rock').filter_by_user_level_of_musical_experience(1, 1)

subset
# Out:
# ElBongoseroCollection with 106 users, total of 111 attempts

# %%
# # Create source drums mapping
# 
# source_drums = []
# for user_data in collection:
#     for attempt_data in user_data.attempts:
#         source_drums.append(attempt_data.drum_path)
#         attempt_data
# source_drums = sorted(list(set(source_drums)))
# 
# source_drums_mapping = {drum: f'source_{i}' for i, drum in enumerate(source_drums)}

# %%
for style in styles:
    subset_style = collection.filter_by_style(style)
    for experience in range(1, 6):
        subset = subset_style.filter_by_user_level_of_musical_experience(experience, experience)
        cnt = 0
        for i, user_data in enumerate(subset):
            for j, attempt_data in enumerate(user_data.attempts):
                try:
                    cnt += 1
                    # hvo_seq_drum = attempt_data.load_source_drum_hvo_seq()
                    # hvo_seq_drum.save_hvo_to_midi(f"midi_organized_by_experience/{style}/experience_{experience-1}/{cnt}/drum.mid")
                    hvo_seq_bongo = attempt_data.load_bongo_loop_hvo_seq()
                    hvo_seq_bongo.save_hvo_to_midi(f"midi_organized_by_experience/{style}/experience_{experience-1}/{cnt}/bongo.mid")
                    hvo_seq_drum_and_bongo = attempt_data.load_drums_with_bongos_hvo_sequence()
                    hvo_seq_drum_and_bongo.save_hvo_to_midi(f"midi_organized_by_experience/{style}/experience_{experience-1}/{cnt}/drum_and_bongo.mid")
                except Exception as e:
                    print(e)
                    continue
# Out:
# Value out of range: 3401614098432
# Value out of range: 2768240640
# data byte must be in range 0..127
# Value out of range: 14831058944
# data byte must be in range 0..127
# Value out of range: 11609833472
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 12683575296
# data byte must be in range 0..127
# Value out of range: 2785017856
# Value out of range: 3456106496
# data byte must be in range 0..127
# Value out of range: 217969590272
# Value out of range: 51539607552
# Value out of range: 3472883712
# Value out of range: 230854492160
# Value out of range: 11475615744
# data byte must be in range 0..127
# Value out of range: 2181038080
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 49392123904
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2550136832
# data byte must be in range 0..127
# Value out of range: 846108557312
# Value out of range: 3187671040
# Value out of range: 13757317120
# Value out of range: 2986344448
# Value out of range: 2919235584
# Value out of range: 44291850240
# data byte must be in range 0..127
# Value out of range: 3841982464
# data byte must be in range 0..127
# Value out of range: 200789721088
# Value out of range: 241591910400
# Value out of range: 49392123904
# Value out of range: 2264924160
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2818572287
# data byte must be in range 0..127
# Value out of range: 3506438144
# Value out of range: 52881784832
# data byte must be in range 0..127
# Value out of range: 196494753792
# Value out of range: 11811160064
# data byte must be in range 0..127
# Value out of range: 11609833472
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 52613349376
# Value out of range: 190052302848
# data byte must be in range 0..127
# Value out of range: 3019898880
# Value out of range: 2473901162496
# data byte must be in range 0..127
# Value out of range: 10401873920
# Value out of range: 3058016714752
# Value out of range: 2868903936
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 3422552064
# data byte must be in range 0..127
# Value out of range: 3439329280
# Value out of range: 10133438464
# Value out of range: 9932111872
# Value out of range: 13757317120
# Value out of range: 2902458368
# Value out of range: 11274289151
# Value out of range: 13086228480
# Value out of range: 13354663935
# data byte must be in range 0..127
# Value out of range: 14159970304
# Value out of range: 2365587456
# Value out of range: 3338665983
# Value out of range: 3305111552
# Value out of range: 13812614823935
# Value out of range: 50197430272
# Value out of range: 12146704384
# data byte must be in range 0..127
# Value out of range: 704374636544
# Value out of range: 3892314111
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2365587456
# Value out of range: 10670309376
# Value out of range: 13488881663
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 14898167808
# data byte must be in range 0..127
# Value out of range: 3170893824
# Value out of range: 3271557120
# Value out of range: 2533359616
# Value out of range: 2868903936
# Value out of range: 2801795071
# data byte must be in range 0..127
# Value out of range: 12348030976
# Value out of range: 9865003008
# Value out of range: 180388626431
# Value out of range: 182536110080
# Value out of range: 3590324224
# Value out of range: 2731599200256
# Value out of range: 48855252992
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 3758096384
# Value out of range: 3523215360
# data byte must be in range 0..127
# Value out of range: 12750684160
# data byte must be in range 0..127
# Value out of range: 2751463424
# Value out of range: 2885681152
# data byte must be in range 0..127
# Value out of range: 10401873920
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 53687091199
# data byte must be in range 0..127
# Value out of range: 12616466432
# Value out of range: 2667577344
# data byte must be in range 0..127
# Value out of range: 14361296896
# Value out of range: 50465865728
# data byte must be in range 0..127
# Value out of range: 58518929408
# data byte must be in range 0..127
# Value out of range: 48049946624
# Value out of range: 11341398016
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 811748818944
# Value out of range: 41875931136
# Value out of range: 3305111552
# Value out of range: 46170898432
# Value out of range: 53687091199
# data byte must be in range 0..127
# Value out of range: 3170893824
# Value out of range: 2533359616
# Value out of range: 3271557120
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2986344448
# Value out of range: 2902458368
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 11475615744
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2902458368
# Value out of range: 14629732352
# Value out of range: 2902458368
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2801795071
# Value out of range: 13287555072
# data byte must be in range 0..127
# Value out of range: 3556769792
# Value out of range: 12415139840
# Value out of range: 13757317120
# Value out of range: 3103784960
# Value out of range: 3506438144
# data byte must be in range 0..127
# Value out of range: 3238002688
# Value out of range: 2734686208
# Value out of range: 2936012800
# Value out of range: 3942645760
# Value out of range: 2818572287
# Value out of range: 2415919104
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 48586817536
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 3472883712
# Value out of range: 3053453312
# Value out of range: 10804527104
# data byte must be in range 0..127
# Value out of range: 3506438144
# Value out of range: 52881784832
# Value out of range: 13354663935
# Value out of range: 54760833024
# data byte must be in range 0..127
# Value out of range: 3143916060672
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 14159970304
# Value out of range: 3388997631
# Value out of range: 2617245696
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 241591910400
# Value out of range: 3388997631
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2583691264
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 614180323328
# Value out of range: 10603200512
# Value out of range: 15837691904
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 204010946560
# Value out of range: 15233712128
# Value out of range: 3254779904
# Value out of range: 13421772799
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2936012800
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 3221225472
# Value out of range: 237296943104
# data byte must be in range 0..127
# Value out of range: 9328132096
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 57445187584
# data byte must be in range 0..127
# Value out of range: 9730785280
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 55297703936
# Value out of range: 2281701376
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 11878268928
# Value out of range: 3875536895
# data byte must be in range 0..127
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 2466250752
# Value out of range: 3841982464
# Value out of range: 3590324224
# Value out of range: 12549357568
# Value out of range: 3657433088
# Value out of range: 14294188032
# Value out of range: 14092861440
# data byte must be in range 0..127
# Value out of range: 12213813248
# data byte must be in range 0..127
# Value out of range: 3321888768
# Value out of range: 3674210304
# data byte must be in range 0..127
# Value out of range: 38923141120
# Value out of range: 2650800128
# data byte must be in range 0..127
# Value out of range: 1513209474796486656
# Value out of range: 1769526525952
# Value out of range: 5905580032
# Value out of range: 23353884672
# Value out of range: 699289395265536
# Value out of range: 26388279066624
# data byte must be in range 0..127
# Value out of range: 3053453312
# Value out of range: 2717908992
# Value out of range: 14144117579710464
# Value out of range: 45634027519
# data byte must be in range 0..127
# data byte must be in range 0..127
# Value out of range: 187904819200
# data byte must be in range 0..127
# Value out of range: 206158430208
# Value out of range: 2886218022911
# Value out of range: 36238786560
# Value out of range: 2005509209063424
# Value out of range: 7918845952
# Value out of range: 2900318160026599424
# Value out of range: 176093659136
# Value out of range: 85899345920
# Value out of range: 14428405760
# Value out of range: 9359042975629312
# Value out of range: 34628173824
# data byte must be in range 0..127
# Value out of range: 721554505727
# Value out of range: 13331578486784
# Value out of range: 164282499072
# Value out of range: 44291850240
# Value out of range: 47553877901312
# Value out of range: 2449473536
# data byte must be in range 0..127
# Value out of range: 36283883716608
# Value out of range: 40681930227712
# data byte must be in range 0..127
# Value out of range: 53326313947136
# Value out of range: 2852126720
# Value out of range: 141733920768
# Value out of range: 11072962560
# data byte must be in range 0..127
# Value out of range: 6442450944
# Value out of range: 691489734656
# Value out of range: 6979321856
# data byte must be in range 0..127
# Value out of range: 15032385536
# data byte must be in range 0..127
# Value out of range: 185817465094144
# data byte must be in range 0..127
# Value out of range: 24159191040
# Value out of range: 166429982720
# Value out of range: 21206401024
# Value out of range: 2851858284544
